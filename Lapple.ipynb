# %%
import matplotlib.pyplot as plt #biblioteca para gerar Grafico

# %%
k = 0.095;     # constante tabelada Lapple
p = 0.00125;   # densidade do ar [g/cm³]
u = 0.196;     # Viscosidade Cinematica do Ar [cm²/s]
pp = 0.97;      # densidade da particula [g/cm³]
d = 200;        # Diametro do Ciclone [cm]
q = [];        # Array Vazão
f = [];        # Array Diametro de corte
v = [];        # Array Velocidade

# %%
for i in range(5, 21, 1):                                    #Intervalo de Velocidades 5 a 20[m/s]
    q.append(i*(0.125*d**2)*100);                            #Vazão de entrada [cm³/s]
    f.append((k*d*((u*d)/(q[i-5]*((pp/p)-1))**(1/2))*10000));    #Diametro de Corte [µm]
    v.append(i);                                             #Velocidade [m/s]

# %%
plt.plot(v,f)
plt.axis([4, 22, 0, 200])
plt.xlabel('Velocidade [m/s]')
plt.ylabel('Diametro de corte [µm]')
plt.suptitle('Lapple')
plt.show()

# %%
n = [];   # Array eficiencia individual de coleta
z = [];   # Array diametro de Particula
w = 17;   # Velocidade a qual sera operado o equipamento

# %%
# Eficiencia de Coleta por diametro de particula

for j in range(1, 800, 1):                      # particulas de 1µm a 800µm
    n.append(((j/(7.6/1000000))**2)/(1+(j/(7.6/1000000))**2)); # Calcula a Eficiencia da particula j
    z.append(j);                                 # Tamanho da particula j

# %%
plt.plot(z,n)
plt.
plt.xlabel('Diametro de Particula [µm]')
plt.ylabel('Eficiencia de Coleta')
plt.suptitle('Lapple')
plt.show()

# %%
print (q)
# Out:
# [2500000.0, 3000000.0, 3500000.0, 4000000.0, 4500000.0, 5000000.0, 5500000.0, 6000000.0, 6500000.0, 7000000.0, 7500000.0, 8000000.0, 8500000.0, 9000000.0, 9500000.0, 10000000.0]
